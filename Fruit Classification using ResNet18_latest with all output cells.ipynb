# %%
from fastai.vision import *
from fastai.metrics import error_rate
import os

# %% [markdown]
# Copying Data set from my Kaggle repo to temporary so that I can have write acess to the dataset.

# %%
cp -r /kaggle/input/fruits/fruits-360_dataset/ /tmp

# %% [markdown]
# Deleting the Vegetable folders from the dataset.

# %%
import shutil
i=0
vegetables=['Apple Braeburn', 'Grape White 2', 'Apple Red Yellow 1', 'Grape White 3', 'Apple Red Yellow 2', 'Grape White 4']
for dirname, _, filenames in os.walk('/tmp/fruits-360_dataset/fruits-360/Training/'): 
    if dirname.split("/")[-1] in vegetables :
        print (dirname)
        shutil.rmtree(dirname)
for dirname, _, filenames in os.walk('/tmp/fruits-360_dataset/fruits-360/Test/'): 
    if dirname.split("/")[-1] in vegetables :
        print (dirname)
        shutil.rmtree(dirname)
shutil.rmtree('/tmp/fruits-360_dataset/fruits-360/test-multiple_fruits')
# Out:
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Braeburn
# /tmp/fruits-360_dataset/fruits-360/Training/Grape White 2
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red Yellow 1
# /tmp/fruits-360_dataset/fruits-360/Training/Grape White 3
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red Yellow 2
# /tmp/fruits-360_dataset/fruits-360/Training/Grape White 4
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Braeburn
# /tmp/fruits-360_dataset/fruits-360/Test/Grape White 2
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red Yellow 1
# /tmp/fruits-360_dataset/fruits-360/Test/Grape White 3
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red Yellow 2
# /tmp/fruits-360_dataset/fruits-360/Test/Grape White 4

# %% [markdown]
# Printing the processed data not having the folders with the vegetables in the test and training both parts,

# %%
i=0
for dirname, _, filenames in os.walk('/tmp/fruits-360_dataset/fruits-360/Training/'): 
    i+=1
    print(dirname,i)
i=0
for dirname, _, filenames in os.walk('/tmp/fruits-360_dataset/fruits-360/Test/'): 
    i+=1
    print(dirname,i)
# Out:
# /tmp/fruits-360_dataset/fruits-360/Training/ 1
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato 3 2
# /tmp/fruits-360_dataset/fruits-360/Training/Pineapple 3
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato Yellow 4
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Pink Lady 5
# /tmp/fruits-360_dataset/fruits-360/Training/Beetroot 6
# /tmp/fruits-360_dataset/fruits-360/Training/Apricot 7
# /tmp/fruits-360_dataset/fruits-360/Training/Onion Red 8
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Kaiser 9
# /tmp/fruits-360_dataset/fruits-360/Training/Chestnut 10
# /tmp/fruits-360_dataset/fruits-360/Training/Pepino 11
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red Delicious 12
# /tmp/fruits-360_dataset/fruits-360/Training/Pepper Yellow 13
# /tmp/fruits-360_dataset/fruits-360/Training/Potato Red 14
# /tmp/fruits-360_dataset/fruits-360/Training/Eggplant 15
# /tmp/fruits-360_dataset/fruits-360/Training/Ginger Root 16
# /tmp/fruits-360_dataset/fruits-360/Training/Mango 17
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry 1 18
# /tmp/fruits-360_dataset/fruits-360/Training/Lemon Meyer 19
# /tmp/fruits-360_dataset/fruits-360/Training/Quince 20
# /tmp/fruits-360_dataset/fruits-360/Training/Kumquats 21
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red 3 22
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato 2 23
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato 1 24
# /tmp/fruits-360_dataset/fruits-360/Training/Plum 3 25
# /tmp/fruits-360_dataset/fruits-360/Training/Limes 26
# /tmp/fruits-360_dataset/fruits-360/Training/Plum 2 27
# /tmp/fruits-360_dataset/fruits-360/Training/Grape Pink 28
# /tmp/fruits-360_dataset/fruits-360/Training/Kaki 29
# /tmp/fruits-360_dataset/fruits-360/Training/Lemon 30
# /tmp/fruits-360_dataset/fruits-360/Training/Mango Red 31
# /tmp/fruits-360_dataset/fruits-360/Training/Orange 32
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red 1 33
# /tmp/fruits-360_dataset/fruits-360/Training/Strawberry 34
# /tmp/fruits-360_dataset/fruits-360/Training/Grapefruit Pink 35
# /tmp/fruits-360_dataset/fruits-360/Training/Pepper Green 36
# /tmp/fruits-360_dataset/fruits-360/Training/Melon Piel de Sapo 37
# /tmp/fruits-360_dataset/fruits-360/Training/Clementine 38
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Monster 39
# /tmp/fruits-360_dataset/fruits-360/Training/Pomelo Sweetie 40
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato 4 41
# /tmp/fruits-360_dataset/fruits-360/Training/Potato White 42
# /tmp/fruits-360_dataset/fruits-360/Training/Blueberry 43
# /tmp/fruits-360_dataset/fruits-360/Training/Peach 44
# /tmp/fruits-360_dataset/fruits-360/Training/Carambula 45
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry Wax Black 46
# /tmp/fruits-360_dataset/fruits-360/Training/Grape White 47
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Golden 2 48
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Crimson Snow 49
# /tmp/fruits-360_dataset/fruits-360/Training/Hazelnut 50
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Granny Smith 51
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato Cherry Red 52
# /tmp/fruits-360_dataset/fruits-360/Training/Mangostan 53
# /tmp/fruits-360_dataset/fruits-360/Training/Salak 54
# /tmp/fruits-360_dataset/fruits-360/Training/Mandarine 55
# /tmp/fruits-360_dataset/fruits-360/Training/Banana 56
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Red 2 57
# /tmp/fruits-360_dataset/fruits-360/Training/Cantaloupe 2 58
# /tmp/fruits-360_dataset/fruits-360/Training/Granadilla 59
# /tmp/fruits-360_dataset/fruits-360/Training/Strawberry Wedge 60
# /tmp/fruits-360_dataset/fruits-360/Training/Potato Sweet 61
# /tmp/fruits-360_dataset/fruits-360/Training/Onion Red Peeled 62
# /tmp/fruits-360_dataset/fruits-360/Training/Physalis 63
# /tmp/fruits-360_dataset/fruits-360/Training/Banana Red 64
# /tmp/fruits-360_dataset/fruits-360/Training/Pear 65
# /tmp/fruits-360_dataset/fruits-360/Training/Rambutan 66
# /tmp/fruits-360_dataset/fruits-360/Training/Mulberry 67
# /tmp/fruits-360_dataset/fruits-360/Training/Kiwi 68
# /tmp/fruits-360_dataset/fruits-360/Training/Tangelo 69
# /tmp/fruits-360_dataset/fruits-360/Training/Lychee 70
# /tmp/fruits-360_dataset/fruits-360/Training/Nectarine 71
# /tmp/fruits-360_dataset/fruits-360/Training/Pitahaya Red 72
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Red 73
# /tmp/fruits-360_dataset/fruits-360/Training/Kohlrabi 74
# /tmp/fruits-360_dataset/fruits-360/Training/Tamarillo 75
# /tmp/fruits-360_dataset/fruits-360/Training/Papaya 76
# /tmp/fruits-360_dataset/fruits-360/Training/Guava 77
# /tmp/fruits-360_dataset/fruits-360/Training/Avocado ripe 78
# /tmp/fruits-360_dataset/fruits-360/Training/Raspberry 79
# /tmp/fruits-360_dataset/fruits-360/Training/Potato Red Washed 80
# /tmp/fruits-360_dataset/fruits-360/Training/Redcurrant 81
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Golden 1 82
# /tmp/fruits-360_dataset/fruits-360/Training/Nectarine Flat 83
# /tmp/fruits-360_dataset/fruits-360/Training/Physalis with Husk 84
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Forelle 85
# /tmp/fruits-360_dataset/fruits-360/Training/Pomegranate 86
# /tmp/fruits-360_dataset/fruits-360/Training/Pineapple Mini 87
# /tmp/fruits-360_dataset/fruits-360/Training/Pepper Red 88
# /tmp/fruits-360_dataset/fruits-360/Training/Nut Pecan 89
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry Wax Yellow 90
# /tmp/fruits-360_dataset/fruits-360/Training/Cantaloupe 1 91
# /tmp/fruits-360_dataset/fruits-360/Training/Onion White 92
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Abate 93
# /tmp/fruits-360_dataset/fruits-360/Training/Cactus fruit 94
# /tmp/fruits-360_dataset/fruits-360/Training/Plum 95
# /tmp/fruits-360_dataset/fruits-360/Training/Banana Lady Finger 96
# /tmp/fruits-360_dataset/fruits-360/Training/Peach 2 97
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry 2 98
# /tmp/fruits-360_dataset/fruits-360/Training/Walnut 99
# /tmp/fruits-360_dataset/fruits-360/Training/Dates 100
# /tmp/fruits-360_dataset/fruits-360/Training/Cocos 101
# /tmp/fruits-360_dataset/fruits-360/Training/Nut Forest 102
# /tmp/fruits-360_dataset/fruits-360/Training/Cauliflower 103
# /tmp/fruits-360_dataset/fruits-360/Training/Grape Blue 104
# /tmp/fruits-360_dataset/fruits-360/Training/Maracuja 105
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry Rainier 106
# /tmp/fruits-360_dataset/fruits-360/Training/Peach Flat 107
# /tmp/fruits-360_dataset/fruits-360/Training/Passion Fruit 108
# /tmp/fruits-360_dataset/fruits-360/Training/Cherry Wax Red 109
# /tmp/fruits-360_dataset/fruits-360/Training/Huckleberry 110
# /tmp/fruits-360_dataset/fruits-360/Training/Grapefruit White 111
# /tmp/fruits-360_dataset/fruits-360/Training/Apple Golden 3 112
# /tmp/fruits-360_dataset/fruits-360/Training/Tomato Maroon 113
# /tmp/fruits-360_dataset/fruits-360/Training/Avocado 114
# /tmp/fruits-360_dataset/fruits-360/Training/Pear Williams 115
# /tmp/fruits-360_dataset/fruits-360/Test/ 1
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato 3 2
# /tmp/fruits-360_dataset/fruits-360/Test/Pineapple 3
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato Yellow 4
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Pink Lady 5
# /tmp/fruits-360_dataset/fruits-360/Test/Beetroot 6
# /tmp/fruits-360_dataset/fruits-360/Test/Apricot 7
# /tmp/fruits-360_dataset/fruits-360/Test/Onion Red 8
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Kaiser 9
# /tmp/fruits-360_dataset/fruits-360/Test/Chestnut 10
# /tmp/fruits-360_dataset/fruits-360/Test/Pepino 11
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red Delicious 12
# /tmp/fruits-360_dataset/fruits-360/Test/Pepper Yellow 13
# /tmp/fruits-360_dataset/fruits-360/Test/Potato Red 14
# /tmp/fruits-360_dataset/fruits-360/Test/Eggplant 15
# /tmp/fruits-360_dataset/fruits-360/Test/Ginger Root 16
# /tmp/fruits-360_dataset/fruits-360/Test/Mango 17
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry 1 18
# /tmp/fruits-360_dataset/fruits-360/Test/Lemon Meyer 19
# /tmp/fruits-360_dataset/fruits-360/Test/Quince 20
# /tmp/fruits-360_dataset/fruits-360/Test/Kumquats 21
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red 3 22
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato 2 23
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato 1 24
# /tmp/fruits-360_dataset/fruits-360/Test/Plum 3 25
# /tmp/fruits-360_dataset/fruits-360/Test/Limes 26
# /tmp/fruits-360_dataset/fruits-360/Test/Plum 2 27
# /tmp/fruits-360_dataset/fruits-360/Test/Grape Pink 28
# /tmp/fruits-360_dataset/fruits-360/Test/Kaki 29
# /tmp/fruits-360_dataset/fruits-360/Test/Lemon 30
# /tmp/fruits-360_dataset/fruits-360/Test/Mango Red 31
# /tmp/fruits-360_dataset/fruits-360/Test/Orange 32
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red 1 33
# /tmp/fruits-360_dataset/fruits-360/Test/Strawberry 34
# /tmp/fruits-360_dataset/fruits-360/Test/Grapefruit Pink 35
# /tmp/fruits-360_dataset/fruits-360/Test/Pepper Green 36
# /tmp/fruits-360_dataset/fruits-360/Test/Melon Piel de Sapo 37
# /tmp/fruits-360_dataset/fruits-360/Test/Clementine 38
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Monster 39
# /tmp/fruits-360_dataset/fruits-360/Test/Pomelo Sweetie 40
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato 4 41
# /tmp/fruits-360_dataset/fruits-360/Test/Potato White 42
# /tmp/fruits-360_dataset/fruits-360/Test/Blueberry 43
# /tmp/fruits-360_dataset/fruits-360/Test/Peach 44
# /tmp/fruits-360_dataset/fruits-360/Test/Carambula 45
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry Wax Black 46
# /tmp/fruits-360_dataset/fruits-360/Test/Grape White 47
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Golden 2 48
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Crimson Snow 49
# /tmp/fruits-360_dataset/fruits-360/Test/Hazelnut 50
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Granny Smith 51
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato Cherry Red 52
# /tmp/fruits-360_dataset/fruits-360/Test/Mangostan 53
# /tmp/fruits-360_dataset/fruits-360/Test/Salak 54
# /tmp/fruits-360_dataset/fruits-360/Test/Mandarine 55
# /tmp/fruits-360_dataset/fruits-360/Test/Banana 56
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Red 2 57
# /tmp/fruits-360_dataset/fruits-360/Test/Cantaloupe 2 58
# /tmp/fruits-360_dataset/fruits-360/Test/Granadilla 59
# /tmp/fruits-360_dataset/fruits-360/Test/Strawberry Wedge 60
# /tmp/fruits-360_dataset/fruits-360/Test/Potato Sweet 61
# /tmp/fruits-360_dataset/fruits-360/Test/Onion Red Peeled 62
# /tmp/fruits-360_dataset/fruits-360/Test/Physalis 63
# /tmp/fruits-360_dataset/fruits-360/Test/Banana Red 64
# /tmp/fruits-360_dataset/fruits-360/Test/Pear 65
# /tmp/fruits-360_dataset/fruits-360/Test/Rambutan 66
# /tmp/fruits-360_dataset/fruits-360/Test/Mulberry 67
# /tmp/fruits-360_dataset/fruits-360/Test/Kiwi 68
# /tmp/fruits-360_dataset/fruits-360/Test/Tangelo 69
# /tmp/fruits-360_dataset/fruits-360/Test/Lychee 70
# /tmp/fruits-360_dataset/fruits-360/Test/Nectarine 71
# /tmp/fruits-360_dataset/fruits-360/Test/Pitahaya Red 72
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Red 73
# /tmp/fruits-360_dataset/fruits-360/Test/Kohlrabi 74
# /tmp/fruits-360_dataset/fruits-360/Test/Tamarillo 75
# /tmp/fruits-360_dataset/fruits-360/Test/Papaya 76
# /tmp/fruits-360_dataset/fruits-360/Test/Guava 77
# /tmp/fruits-360_dataset/fruits-360/Test/Avocado ripe 78
# /tmp/fruits-360_dataset/fruits-360/Test/Raspberry 79
# /tmp/fruits-360_dataset/fruits-360/Test/Potato Red Washed 80
# /tmp/fruits-360_dataset/fruits-360/Test/Redcurrant 81
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Golden 1 82
# /tmp/fruits-360_dataset/fruits-360/Test/Nectarine Flat 83
# /tmp/fruits-360_dataset/fruits-360/Test/Physalis with Husk 84
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Forelle 85
# /tmp/fruits-360_dataset/fruits-360/Test/Pomegranate 86
# /tmp/fruits-360_dataset/fruits-360/Test/Pineapple Mini 87
# /tmp/fruits-360_dataset/fruits-360/Test/Pepper Red 88
# /tmp/fruits-360_dataset/fruits-360/Test/Nut Pecan 89
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry Wax Yellow 90
# /tmp/fruits-360_dataset/fruits-360/Test/Cantaloupe 1 91
# /tmp/fruits-360_dataset/fruits-360/Test/Onion White 92
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Abate 93
# /tmp/fruits-360_dataset/fruits-360/Test/Cactus fruit 94
# /tmp/fruits-360_dataset/fruits-360/Test/Plum 95
# /tmp/fruits-360_dataset/fruits-360/Test/Banana Lady Finger 96
# /tmp/fruits-360_dataset/fruits-360/Test/Peach 2 97
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry 2 98
# /tmp/fruits-360_dataset/fruits-360/Test/Walnut 99
# /tmp/fruits-360_dataset/fruits-360/Test/Dates 100
# /tmp/fruits-360_dataset/fruits-360/Test/Cocos 101
# /tmp/fruits-360_dataset/fruits-360/Test/Nut Forest 102
# /tmp/fruits-360_dataset/fruits-360/Test/Cauliflower 103
# /tmp/fruits-360_dataset/fruits-360/Test/Grape Blue 104
# /tmp/fruits-360_dataset/fruits-360/Test/Maracuja 105
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry Rainier 106
# /tmp/fruits-360_dataset/fruits-360/Test/Peach Flat 107
# /tmp/fruits-360_dataset/fruits-360/Test/Passion Fruit 108
# /tmp/fruits-360_dataset/fruits-360/Test/Cherry Wax Red 109
# /tmp/fruits-360_dataset/fruits-360/Test/Huckleberry 110
# /tmp/fruits-360_dataset/fruits-360/Test/Grapefruit White 111
# /tmp/fruits-360_dataset/fruits-360/Test/Apple Golden 3 112
# /tmp/fruits-360_dataset/fruits-360/Test/Tomato Maroon 113
# /tmp/fruits-360_dataset/fruits-360/Test/Avocado 114
# /tmp/fruits-360_dataset/fruits-360/Test/Pear Williams 115

# %% [markdown]
# Path for Data Set

# %%
path= '/tmp/fruits-360_dataset/fruits-360/'

# %% [markdown]
# Test folder path

# %%
test_folder='/tmp/fruits-360_dataset/fruits-360/Test'
# src = (ImageList.from_folder(path)
#        .split_by_rand_pct(valid_pct=0.2)
#        .label_from_folder()
#        .transform(get_transforms(), size=256)
#        )
# data = (src.databunch(bs=512)
#         .normalize(imagenet_stats))

# data.show_batch(rows=3,figsize=(8,8))

# %% [markdown]
# Creating the training and validation data with 80-20 ratio and getting the ground truth labels from folder names.
# Batch size=512
# The data is normalized w.r.t imagenet_stats

# %%
data=ImageDataBunch.from_folder(path,size=256,valid_pct=0.2,test=test_folder ,ds_tfms=get_transforms(),bs=512).normalize(imagenet_stats)

# %% [markdown]
# Showing the data to check if loaded properly

# %%
data.show_batch(rows=3,fig_size=(5,5))

# %%
len(data.classes)
# Out:
# 114

# %%
 data.c, len(data.train_ds), len(data.valid_ds), len(data.test_ds)
# Out:
# (114, 45912, 11477, 19587)

# %% [markdown]
# Loading ResNet-18 and setting the metrics to improve as accuracy. We also have set the call back function which helps us in plotting the train and validation loss while fitting the model.

# %%
learner18=cnn_learner(data,models.resnet18,metrics=accuracy, callback_fns=ShowGraph)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %% [markdown]
# Finding the best learning rate for the model so that the loss is reduced to increase the precision of the model.

# %%
learner18.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 05:07<05:07]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.170037</td>
#       <td>#na#</td>
#       <td>05:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='89', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.12% [1/89 00:07<11:02 12.0740]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Plotting the learning rate with a suggestion where there is a significant imprivement in the loss.

# %%
learner18.recorder.plot(suggestion=True)
# Out:
# Min numerical gradient: 5.25E-03
# Min loss divided by 10: 3.02E-02

# %% [markdown]
# Fitting our ResNet-18 Model for 4 epochs with the max learning rate set to the best as found in the previous graph.

# %%
learner18.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.894814</td>
#       <td>0.015607</td>
#       <td>0.998867</td>
#       <td>05:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.185154</td>
#       <td>0.006486</td>
#       <td>0.999564</td>
#       <td>05:41</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Initially the model is freezed and only the last few layers are trained. We unfreeze the layers and train on all the layers to have improvement in the error rate.

# %%
learner18.unfreeze()
learner18.fit_one_cycle(2,max_lr=slice(1e-6,1e-4))
learner18.save('learn-stage7')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.049080</td>
#       <td>0.003488</td>
#       <td>0.999913</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.037495</td>
#       <td>0.002597</td>
#       <td>0.999913</td>
#       <td>05:49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Printing the summary of the model for better understanding.

# %%
learner18.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 128, 128]       9,408      True
# ______________________________________________________________________
# BatchNorm2d          [64, 128, 128]       128        True
# ______________________________________________________________________
# ReLU                 [64, 128, 128]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# ReLU                 [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# ReLU                 [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# ReLU                 [128, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        8,192      True
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# ReLU                 [128, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# ReLU                 [256, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        32,768     True
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# ReLU                 [256, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          1,179,648  True
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          131,072    True
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Flatten              [1024]               0          False
# ______________________________________________________________________
# BatchNorm1d          [1024]               2,048      True
# ______________________________________________________________________
# Dropout              [1024]               0          False
# ______________________________________________________________________
# Linear               [512]                524,800    True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [114]                58,482     True
# ______________________________________________________________________
#
# Total params: 11,762,866
# Total trainable params: 11,762,866
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
interp=ClassificationInterpretation.from_learner(learner18)
interp.plot_top_losses(9,figsize=(12,12))

# %% [markdown]
# # Confusion Matrix on the Validation set.

# %%
interp.plot_confusion_matrix(figsize=(20,20))

# %% [markdown]
# # **Accuracy on Validation data.**

# %%
learner18.validate()
# Out:
# [0.0025966791, tensor(0.9999)]

# %%
learner18.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (45912 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360;
#
# Valid: LabelList (11477 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Apple Granny Smith,Grape Blue,Avocado ripe,Pepper Green,Strawberry
# Path: /tmp/fruits-360_dataset/fruits-360;
#
# Test: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: EmptyLabelList
# ,,,,
# Path: /tmp/fruits-360_dataset/fruits-360

# %%
learner18.validate(data.test_dl)

# %% [markdown]
# # Preparation on changing the validation set of the model to the test data.
# This is done as fastai supports unlabelled data in the test data as of now and validating the data manually would be cumbersome task when the data is already labelled and provided in a particular format.
# We basically create a new ImageDataBunch having the Test data in it and set the same parameters as our data in the previous step while feeding it to our model. Then we pass this new data to the original model's validation set and then validate and create a ClassificationInterpretation to have the confusion matrix and other results this time on the test data set which is never seen by the model.

# %%
learn=learner18

# %%
learn.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (45912 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360;
#
# Valid: LabelList (11477 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Apple Granny Smith,Grape Blue,Avocado ripe,Pepper Green,Strawberry
# Path: /tmp/fruits-360_dataset/fruits-360;
#
# Test: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: EmptyLabelList
# ,,,,
# Path: /tmp/fruits-360_dataset/fruits-360

# %%
il = ImageList.from_folder(path=test_folder)
ils = il.split_none() 
ll = ils.label_from_folder()
ll.valid = ll.train
ll.transform(tfms=None,size=256) 
data2 = ll.databunch(bs=512);
data2.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360/Test;
#
# Valid: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360/Test;
#
# Test: None

# %%
learn.data.valid_dl = data2.valid_dl

# %%
learn.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (45912 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360;
#
# Valid: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# Tomato 3,Tomato 3,Tomato 3,Tomato 3,Tomato 3
# Path: /tmp/fruits-360_dataset/fruits-360/Test;
#
# Test: LabelList (19587 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: EmptyLabelList
# ,,,,
# Path: /tmp/fruits-360_dataset/fruits-360

# %% [markdown]
# # Confusion matrix on the Test Data.

# %%
interp = ClassificationInterpretation.from_learner(learn,ds_type=DatasetType.Valid)
interp.plot_confusion_matrix(figsize=(20,20))

# %% [markdown]
# # Accuracy on the Test Data

# %%
interp.plot_top_losses(9,figsize=(14,14))

# %%
learn.validate()
# Out:
# [0.026556948, tensor(0.9934)]

# %%
interp.most_confused()
# Out:
# [('Eggplant', 'Blueberry', 27),
#  ('Pepino', 'Peach Flat', 20),
#  ('Tomato 1', 'Tomato 3', 15),
#  ('Beetroot', 'Potato Red', 8),
#  ('Strawberry Wedge', 'Salak', 8),
#  ('Peach', 'Nectarine', 6),
#  ('Nectarine', 'Peach', 5),
#  ('Apple Red 2', 'Nectarine', 4),
#  ('Pear', 'Apple Golden 3', 4),
#  ('Apple Crimson Snow', 'Apple Pink Lady', 3),
#  ('Beetroot', 'Potato Sweet', 3),
#  ('Eggplant', 'Beetroot', 3),
#  ('Apple Crimson Snow', 'Apple Red 1', 2),
#  ('Apple Red 1', 'Apple Red 2', 2),
#  ('Apple Red 2', 'Apple Pink Lady', 2),
#  ('Apple Red 2', 'Apple Red 1', 2),
#  ('Mangostan', 'Chestnut', 2),
#  ('Nectarine Flat', 'Mango Red', 2),
#  ('Apple Golden 1', 'Physalis with Husk', 1),
#  ('Apple Red 3', 'Peach', 1),
#  ('Beetroot', 'Mangostan', 1),
#  ('Kaki', 'Tomato 2', 1),
#  ('Mango Red', 'Apple Crimson Snow', 1),
#  ('Peach', 'Apple Red 1', 1),
#  ('Pepino', 'Apple Golden 2', 1),
#  ('Pepino', 'Grapefruit White', 1),
#  ('Pepino', 'Peach 2', 1),
#  ('Potato Red', 'Potato Sweet', 1),
#  ('Potato Red Washed', 'Nectarine Flat', 1),
#  ('Strawberry Wedge', 'Avocado ripe', 1)]

# %%
data.classes[26]
# Out:
# 'Cherry Wax Red'
